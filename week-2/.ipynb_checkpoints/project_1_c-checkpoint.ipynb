# %%
name1 = input("Enter first person's name: ")
age1 = int(input(f"Enter {name1}'s age: "))

name2 = input("Enter second person's name: ")
age2 = int(input("Enter {name2}'s age: "))

print("Before swapping:")
print(f"{name1} is {age1} years old")
print(f"{name2} is {age2} years old")

temp = age1
age1 = age2
age2 = temp

print("After swapping:")
print(f"{name1} is now {age1} years old")
print(f"{name2} is now {age2} years old")
# Out:
# Enter first person's name:  dara
# Enter dara's age:  17
# Enter second person's name:  fola
# Enter {name2}'s age:  23
# Before swapping:
# dara is 17 years old
# fola is 23 years old
# After swapping:
# dara is now 23 years old
# fola is now 17 years old

# %% [markdown]
# # PSEUDOCODE

# %%
BEGIN

PRINT "Enter name1"
INPUT name1
PRINT "Enter age1"
INPUT age1

PRINT "Enter name2"
INPUT name2 
PRINT "Enter age2"
INPUT age2

PRINT "name1 is age1"
PRINT "name2 is age2"

SET temp = age1
SET age1 = age2
SET age2 = temp

PRINT name1 "is now" age1 
PRINT name2 "is now" age2

END

# %% [markdown]
# ![Screenshot (95).png](attachment:2e44a660-8b5d-49f9-ad54-285d10d5962e.png)
