# %%
#number
num = 100
print(num)
print("Data Tyoe of variable num is", type(num))

#float number
fnum = 34.45
print(fnum)
print("Data Type of variable fnumis", type(fnum))

#complex number
cnum = 3 + 4j
print(cnum)
print("Data type of variable cnum is", type(cnum))
# Out:
# 100
# Data Tyoe of variable num is <class 'int'>
# 34.45
# Data Type of variable fnumis <class 'float'>
# (3+4j)
# Data type of variable cnum is <class 'complex'>
